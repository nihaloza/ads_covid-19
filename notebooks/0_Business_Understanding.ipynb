# %% [markdown]
# # Business Understanding

# %% [markdown]
# - CRISP- DM

# %% [markdown]
# ![CRISP_DM.jpeg](attachment:CRISP_DM.jpeg)

# %% [markdown]
# We would track the CORONA Virus spread across the countries along with the personal local information

# %% [markdown]
#  # Goal

# %% [markdown]
# Understand the data quality

# %% [markdown]
# Using the best practices of data science from industry develop a COVID-19 analysis prototype

# %% [markdown]
# Complete work should be automated as much as possible (* how many clicks needed to execute the complete work pipeline)

# %% [markdown]
# # Constraints

# %% [markdown]
# Each notebook should be clean and ready for complete execution

# %% [markdown]
# # Video Explanation

# %% [markdown]
# A 3-minute video to expalin how the work was developed and display the results
